# %%
# %%capture
# !apt install -y python3-opengl
# !apt install -y ffmpeg
# !apt install -y xvfb
# !pip3 install pyvirtualdisplay

# %%
from pyvirtualdisplay import Display

display = Display(visible=0, size=(1400, 900))
display.start()

# %%
# %pip install gymnasium[mujoco] stable-baselines3

clear_output()

# %% [markdown]
# # Task
#
# We will use the SAC algorithm to train the **walker** environment.
#
# You can implement it yourself or use the Stablebaselines3 version.
#
# Walker environment consists of a structure of legs and the agent's actions can move the joints. The goal is to make the structure able to walk.
#
# You can see more about the actions, observations and rewards [here](https://gymnasium.farama.org/environments/mujoco/walker2d/)
#
# ![Walker Image](https://gymnasium.farama.org/_images/walker2d.gif)

# %%
import numpy as np

import gymnasium as gym
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.noise import NormalActionNoise

from IPython.display import clear_output

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %% [markdown]
# ### Creating the environment

# %%
make_env = lambda: gym.make('Walker2d-v4', render_mode='rgb_array')
env = DummyVecEnv([make_env for _ in range(4)])  # adjust accoring to available ram
num_actions = env.action_space.shape[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
noise_mean = np.array([0.0] * num_actions)
noise_std = np.array([0.1] * num_actions)

# %% [markdown]
# ### Training the model

# %%
model = SAC("MlpPolicy",
            env,
            verbose=1,
            action_noise=NormalActionNoise(noise_mean, noise_std),  # noise for exploration
            learning_rate=1e-3)
# Out:
# Using cuda device
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
clear_output()
model.learn(total_timesteps=int(1e6), progress_bar=True)
# Out:
# Output()
# -----------------------------
# | time/              |      |
# |    episodes        | 4    |
# |    fps             | 1669 |
# |    time_elapsed    | 0    |
# |    total_timesteps | 104  |
# -----------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 565      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 164      |
# | train/             |          |
# |    actor_loss      | -7.06    |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.986    |
# |    ent_coef_loss   | -0.139   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 433      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 228      |
# | train/             |          |
# |    actor_loss      | -7.88    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.97     |
# |    ent_coef_loss   | -0.302   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 348      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 328      |
# | train/             |          |
# |    actor_loss      | -8.57    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.946    |
# |    ent_coef_loss   | -0.556   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 56       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 320      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 380      |
# | train/             |          |
# |    actor_loss      | -8.51    |
# |    critic_loss     | 2.05     |
# |    ent_coef        | 0.934    |
# |    ent_coef_loss   | -0.685   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 69       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 308      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 476      |
# | train/             |          |
# |    actor_loss      | -8.95    |
# |    critic_loss     | 0.931    |
# |    ent_coef        | 0.912    |
# |    ent_coef_loss   | -0.929   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 93       |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 291      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 556      |
# | train/             |          |
# |    actor_loss      | -8.88    |
# |    critic_loss     | 1.36     |
# |    ent_coef        | 0.894    |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 113      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 285      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 652      |
# | train/             |          |
# |    actor_loss      | -9.16    |
# |    critic_loss     | 0.811    |
# |    ent_coef        | 0.872    |
# |    ent_coef_loss   | -1.37    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 137      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 274      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 860      |
# | train/             |          |
# |    actor_loss      | -9       |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.828    |
# |    ent_coef_loss   | -1.89    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 189      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 272      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | -9.14    |
# |    critic_loss     | 0.905    |
# |    ent_coef        | 0.8      |
# |    ent_coef_loss   | -2.23    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 224      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 266      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1100     |
# | train/             |          |
# |    actor_loss      | -9.26    |
# |    critic_loss     | 0.686    |
# |    ent_coef        | 0.78     |
# |    ent_coef_loss   | -2.47    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 249      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 265      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1236     |
# | train/             |          |
# |    actor_loss      | -9.23    |
# |    critic_loss     | 0.79     |
# |    ent_coef        | 0.754    |
# |    ent_coef_loss   | -2.81    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 283      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 262      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1388     |
# | train/             |          |
# |    actor_loss      | -9.53    |
# |    critic_loss     | 0.713    |
# |    ent_coef        | 0.726    |
# |    ent_coef_loss   | -3.18    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 321      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 254      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1576     |
# | train/             |          |
# |    actor_loss      | -9.62    |
# |    critic_loss     | 0.705    |
# |    ent_coef        | 0.693    |
# |    ent_coef_loss   | -3.61    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 368      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 237      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1896     |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 0.698    |
# |    ent_coef        | 0.64     |
# |    ent_coef_loss   | -4.33    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 448      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 234      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2208     |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.703    |
# |    ent_coef        | 0.593    |
# |    ent_coef_loss   | -5.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 526      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 235      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2560     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 0.786    |
# |    ent_coef        | 0.545    |
# |    ent_coef_loss   | -5.82    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 614      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 237      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 3196     |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.507    |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -7.08    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 773      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 237      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 3568     |
# | train/             |          |
# |    actor_loss      | -11.9    |
# |    critic_loss     | 0.722    |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -7.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 866      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 233      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 4336     |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.625    |
# |    ent_coef        | 0.359    |
# |    ent_coef_loss   | -8.82    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1058     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 222      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 5168     |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 0.685    |
# |    ent_coef        | 0.298    |
# |    ent_coef_loss   | -10.2    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1266     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 225      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 6024     |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.561    |
# |    ent_coef        | 0.247    |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1480     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 227      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 6644     |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 0.836    |
# |    ent_coef        | 0.216    |
# |    ent_coef_loss   | -11.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1635     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 229      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 7280     |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 0.754    |
# |    ent_coef        | 0.188    |
# |    ent_coef_loss   | -12.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1794     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 224      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 8112     |
# | train/             |          |
# |    actor_loss      | -19.1    |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.157    |
# |    ent_coef_loss   | -12.1    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2002     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 227      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 9292     |
# | train/             |          |
# |    actor_loss      | -21.7    |
# |    critic_loss     | 1.22     |
# |    ent_coef        | 0.122    |
# |    ent_coef_loss   | -12.3    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2297     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 228      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 9984     |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2470     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 228      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 10556    |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 4.05     |
# |    ent_coef        | 0.0939   |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2613     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 226      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 11364    |
# | train/             |          |
# |    actor_loss      | -25.1    |
# |    critic_loss     | 3.36     |
# |    ent_coef        | 0.0799   |
# |    ent_coef_loss   | -12.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2815     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 227      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 12348    |
# | train/             |          |
# |    actor_loss      | -26.3    |
# |    critic_loss     | 3.35     |
# |    ent_coef        | 0.0656   |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3061     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 228      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 13128    |
# | train/             |          |
# |    actor_loss      | -27.4    |
# |    critic_loss     | 2.07     |
# |    ent_coef        | 0.0565   |
# |    ent_coef_loss   | -13.3    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3256     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 226      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 13968    |
# | train/             |          |
# |    actor_loss      | -28.3    |
# |    critic_loss     | 3.61     |
# |    ent_coef        | 0.0484   |
# |    ent_coef_loss   | -7.65    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3466     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 226      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 14680    |
# | train/             |          |
# |    actor_loss      | -28.4    |
# |    critic_loss     | 3.35     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | -14.5    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3644     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 228      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 16360    |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 2.73     |
# |    ent_coef        | 0.0327   |
# |    ent_coef_loss   | -6.89    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4064     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 227      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 17544    |
# | train/             |          |
# |    actor_loss      | -33.4    |
# |    critic_loss     | 5.79     |
# |    ent_coef        | 0.028    |
# |    ent_coef_loss   | -5.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4360     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 227      |
# |    time_elapsed    | 80       |
# |    total_timesteps | 18328    |
# | train/             |          |
# |    actor_loss      | -34      |
# |    critic_loss     | 4.36     |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | -2.87    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4556     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 228      |
# |    time_elapsed    | 84       |
# |    total_timesteps | 19224    |
# | train/             |          |
# |    actor_loss      | -36.8    |
# |    critic_loss     | 3.99     |
# |    ent_coef        | 0.0235   |
# |    ent_coef_loss   | -5.54    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4780     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 226      |
# |    time_elapsed    | 88       |
# |    total_timesteps | 20072    |
# | train/             |          |
# |    actor_loss      | -35.9    |
# |    critic_loss     | 2.93     |
# |    ent_coef        | 0.0217   |
# |    ent_coef_loss   | -5.49    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4992     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 227      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 20568    |
# | train/             |          |
# |    actor_loss      | -37.5    |
# |    critic_loss     | 6.85     |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | -4.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5116     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 227      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 21368    |
# | train/             |          |
# |    actor_loss      | -37.8    |
# |    critic_loss     | 4.23     |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | -8.81    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5316     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 227      |
# |    time_elapsed    | 96       |
# |    total_timesteps | 21908    |
# | train/             |          |
# |    actor_loss      | -40.5    |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | -2.33    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5451     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 226      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 22632    |
# | train/             |          |
# |    actor_loss      | -40.6    |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.0182   |
# |    ent_coef_loss   | -2.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5632     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 226      |
# |    time_elapsed    | 102      |
# |    total_timesteps | 23084    |
# | train/             |          |
# |    actor_loss      | -41.4    |
# |    critic_loss     | 5.44     |
# |    ent_coef        | 0.018    |
# |    ent_coef_loss   | 2.93     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5745     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 226      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 23864    |
# | train/             |          |
# |    actor_loss      | -41.5    |
# |    critic_loss     | 8.56     |
# |    ent_coef        | 0.0177   |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5940     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 227      |
# |    time_elapsed    | 108      |
# |    total_timesteps | 24616    |
# | train/             |          |
# |    actor_loss      | -44.8    |
# |    critic_loss     | 6.19     |
# |    ent_coef        | 0.0176   |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6128     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 226      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 25356    |
# | train/             |          |
# |    actor_loss      | -43.8    |
# |    critic_loss     | 4.61     |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | -1.22    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6313     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 226      |
# |    time_elapsed    | 115      |
# |    total_timesteps | 26040    |
# | train/             |          |
# |    actor_loss      | -46.8    |
# |    critic_loss     | 5.1      |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | -1.59    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6484     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 225      |
# |    time_elapsed    | 117      |
# |    total_timesteps | 26476    |
# | train/             |          |
# |    actor_loss      | -46.8    |
# |    critic_loss     | 4.69     |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | 0.436    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6593     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 224      |
# |    time_elapsed    | 120      |
# |    total_timesteps | 27056    |
# | train/             |          |
# |    actor_loss      | -48      |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -0.979   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6738     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 224      |
# |    time_elapsed    | 124      |
# |    total_timesteps | 28080    |
# | train/             |          |
# |    actor_loss      | -48.2    |
# |    critic_loss     | 7.83     |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | -0.548   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6994     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 224      |
# |    time_elapsed    | 127      |
# |    total_timesteps | 28676    |
# | train/             |          |
# |    actor_loss      | -49      |
# |    critic_loss     | 5.07     |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7143     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 224      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 29364    |
# | train/             |          |
# |    actor_loss      | -49.4    |
# |    critic_loss     | 6.74     |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | 3.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7315     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 225      |
# |    time_elapsed    | 133      |
# |    total_timesteps | 30104    |
# | train/             |          |
# |    actor_loss      | -51.5    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7500     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 225      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 30752    |
# | train/             |          |
# |    actor_loss      | -51.7    |
# |    critic_loss     | 7.15     |
# |    ent_coef        | 0.0217   |
# |    ent_coef_loss   | -0.508   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7662     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 224      |
# |    time_elapsed    | 140      |
# |    total_timesteps | 31616    |
# | train/             |          |
# |    actor_loss      | -54.1    |
# |    critic_loss     | 7.64     |
# |    ent_coef        | 0.0228   |
# |    ent_coef_loss   | 5.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7878     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 224      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 32352    |
# | train/             |          |
# |    actor_loss      | -55.2    |
# |    critic_loss     | 4.63     |
# |    ent_coef        | 0.0244   |
# |    ent_coef_loss   | -2.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8062     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 225      |
# |    time_elapsed    | 147      |
# |    total_timesteps | 33244    |
# | train/             |          |
# |    actor_loss      | -58.3    |
# |    critic_loss     | 7.28     |
# |    ent_coef        | 0.0251   |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8285     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 225      |
# |    time_elapsed    | 150      |
# |    total_timesteps | 33996    |
# | train/             |          |
# |    actor_loss      | -58.5    |
# |    critic_loss     | 7.21     |
# |    ent_coef        | 0.0262   |
# |    ent_coef_loss   | 3.31     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8473     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 224      |
# |    time_elapsed    | 154      |
# |    total_timesteps | 34744    |
# | train/             |          |
# |    actor_loss      | -58.8    |
# |    critic_loss     | 8.08     |
# |    ent_coef        | 0.0259   |
# |    ent_coef_loss   | 0.901    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8660     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 225      |
# |    time_elapsed    | 157      |
# |    total_timesteps | 35580    |
# | train/             |          |
# |    actor_loss      | -61.1    |
# |    critic_loss     | 4.83     |
# |    ent_coef        | 0.0274   |
# |    ent_coef_loss   | 3.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8869     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 225      |
# |    time_elapsed    | 160      |
# |    total_timesteps | 36340    |
# | train/             |          |
# |    actor_loss      | -61.3    |
# |    critic_loss     | 8.44     |
# |    ent_coef        | 0.0277   |
# |    ent_coef_loss   | -3.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9059     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 225      |
# |    time_elapsed    | 163      |
# |    total_timesteps | 37028    |
# | train/             |          |
# |    actor_loss      | -61.8    |
# |    critic_loss     | 5.54     |
# |    ent_coef        | 0.0281   |
# |    ent_coef_loss   | -2.31    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9231     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 225      |
# |    time_elapsed    | 167      |
# |    total_timesteps | 37780    |
# | train/             |          |
# |    actor_loss      | -64.4    |
# |    critic_loss     | 6.81     |
# |    ent_coef        | 0.0283   |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9419     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 225      |
# |    time_elapsed    | 169      |
# |    total_timesteps | 38232    |
# | train/             |          |
# |    actor_loss      | -65      |
# |    critic_loss     | 7.19     |
# |    ent_coef        | 0.028    |
# |    ent_coef_loss   | 0.657    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9532     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 225      |
# |    time_elapsed    | 172      |
# |    total_timesteps | 38916    |
# | train/             |          |
# |    actor_loss      | -65.5    |
# |    critic_loss     | 5.71     |
# |    ent_coef        | 0.0283   |
# |    ent_coef_loss   | -0.00956 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9703     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 225      |
# |    time_elapsed    | 174      |
# |    total_timesteps | 39412    |
# | train/             |          |
# |    actor_loss      | -66.2    |
# |    critic_loss     | 9.25     |
# |    ent_coef        | 0.0284   |
# |    ent_coef_loss   | 3.74     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9827     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 225      |
# |    time_elapsed    | 178      |
# |    total_timesteps | 40324    |
# | train/             |          |
# |    actor_loss      | -66      |
# |    critic_loss     | 8        |
# |    ent_coef        | 0.0293   |
# |    ent_coef_loss   | -3.13    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10055    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 225      |
# |    time_elapsed    | 181      |
# |    total_timesteps | 40948    |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 4.6      |
# |    ent_coef        | 0.0303   |
# |    ent_coef_loss   | -3.27    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10211    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 225      |
# |    time_elapsed    | 185      |
# |    total_timesteps | 41816    |
# | train/             |          |
# |    actor_loss      | -69.3    |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.0293   |
# |    ent_coef_loss   | -2.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10428    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 225      |
# |    time_elapsed    | 188      |
# |    total_timesteps | 42496    |
# | train/             |          |
# |    actor_loss      | -66.4    |
# |    critic_loss     | 8.45     |
# |    ent_coef        | 0.0282   |
# |    ent_coef_loss   | 1.95     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10598    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 225      |
# |    time_elapsed    | 191      |
# |    total_timesteps | 43252    |
# | train/             |          |
# |    actor_loss      | -67.1    |
# |    critic_loss     | 7.14     |
# |    ent_coef        | 0.0284   |
# |    ent_coef_loss   | 2.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10787    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 225      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 44056    |
# | train/             |          |
# |    actor_loss      | -72.9    |
# |    critic_loss     | 9.89     |
# |    ent_coef        | 0.0284   |
# |    ent_coef_loss   | -2.08    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10988    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 225      |
# |    time_elapsed    | 198      |
# |    total_timesteps | 44876    |
# | train/             |          |
# |    actor_loss      | -74.7    |
# |    critic_loss     | 8.14     |
# |    ent_coef        | 0.029    |
# |    ent_coef_loss   | 0.955    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11193    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 226      |
# |    time_elapsed    | 201      |
# |    total_timesteps | 45584    |
# | train/             |          |
# |    actor_loss      | -73.2    |
# |    critic_loss     | 5.97     |
# |    ent_coef        | 0.0282   |
# |    ent_coef_loss   | 0.323    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11370    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 225      |
# |    time_elapsed    | 205      |
# |    total_timesteps | 46320    |
# | train/             |          |
# |    actor_loss      | -73.9    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0292   |
# |    ent_coef_loss   | 4.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11554    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 226      |
# |    time_elapsed    | 209      |
# |    total_timesteps | 47436    |
# | train/             |          |
# |    actor_loss      | -75.1    |
# |    critic_loss     | 8.15     |
# |    ent_coef        | 0.0297   |
# |    ent_coef_loss   | 0.102    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11833    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 226      |
# |    time_elapsed    | 213      |
# |    total_timesteps | 48344    |
# | train/             |          |
# |    actor_loss      | -77      |
# |    critic_loss     | 6.98     |
# |    ent_coef        | 0.0302   |
# |    ent_coef_loss   | 4.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12060    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 226      |
# |    time_elapsed    | 217      |
# |    total_timesteps | 49288    |
# | train/             |          |
# |    actor_loss      | -78.1    |
# |    critic_loss     | 6.02     |
# |    ent_coef        | 0.0292   |
# |    ent_coef_loss   | 0.726    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12296    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 226      |
# |    time_elapsed    | 221      |
# |    total_timesteps | 50104    |
# | train/             |          |
# |    actor_loss      | -77.7    |
# |    critic_loss     | 7.2      |
# |    ent_coef        | 0.0286   |
# |    ent_coef_loss   | -0.113   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12500    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 226      |
# |    time_elapsed    | 223      |
# |    total_timesteps | 50740    |
# | train/             |          |
# |    actor_loss      | -78.4    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0295   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12659    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 227      |
# |    time_elapsed    | 226      |
# |    total_timesteps | 51436    |
# | train/             |          |
# |    actor_loss      | -81.1    |
# |    critic_loss     | 8        |
# |    ent_coef        | 0.0282   |
# |    ent_coef_loss   | -0.175   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12833    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 226      |
# |    time_elapsed    | 230      |
# |    total_timesteps | 52260    |
# | train/             |          |
# |    actor_loss      | -78.7    |
# |    critic_loss     | 9.34     |
# |    ent_coef        | 0.0305   |
# |    ent_coef_loss   | -0.249   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13039    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 226      |
# |    time_elapsed    | 234      |
# |    total_timesteps | 53040    |
# | train/             |          |
# |    actor_loss      | -84.1    |
# |    critic_loss     | 9.88     |
# |    ent_coef        | 0.0303   |
# |    ent_coef_loss   | 1.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13234    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 226      |
# |    time_elapsed    | 236      |
# |    total_timesteps | 53796    |
# | train/             |          |
# |    actor_loss      | -82.2    |
# |    critic_loss     | 5.35     |
# |    ent_coef        | 0.0305   |
# |    ent_coef_loss   | -0.74    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13423    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 227      |
# |    time_elapsed    | 239      |
# |    total_timesteps | 54472    |
# | train/             |          |
# |    actor_loss      | -80.7    |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0306   |
# |    ent_coef_loss   | 1.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13592    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 227      |
# |    time_elapsed    | 243      |
# |    total_timesteps | 55236    |
# | train/             |          |
# |    actor_loss      | -83.3    |
# |    critic_loss     | 8.08     |
# |    ent_coef        | 0.0295   |
# |    ent_coef_loss   | 2.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13783    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 227      |
# |    time_elapsed    | 248      |
# |    total_timesteps | 56360    |
# | train/             |          |
# |    actor_loss      | -81.9    |
# |    critic_loss     | 9.56     |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | 1.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14064    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 227      |
# |    time_elapsed    | 250      |
# |    total_timesteps | 57052    |
# | train/             |          |
# |    actor_loss      | -83.8    |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.0308   |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14237    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 227      |
# |    time_elapsed    | 254      |
# |    total_timesteps | 57964    |
# | train/             |          |
# |    actor_loss      | -86.8    |
# |    critic_loss     | 7.13     |
# |    ent_coef        | 0.0298   |
# |    ent_coef_loss   | 0.173    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14465    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 227      |
# |    time_elapsed    | 259      |
# |    total_timesteps | 58924    |
# | train/             |          |
# |    actor_loss      | -91      |
# |    critic_loss     | 6.71     |
# |    ent_coef        | 0.0282   |
# |    ent_coef_loss   | -3.37    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14705    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 228      |
# |    time_elapsed    | 266      |
# |    total_timesteps | 60788    |
# | train/             |          |
# |    actor_loss      | -89.4    |
# |    critic_loss     | 8.41     |
# |    ent_coef        | 0.0291   |
# |    ent_coef_loss   | 1.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15171    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 227      |
# |    time_elapsed    | 271      |
# |    total_timesteps | 61760    |
# | train/             |          |
# |    actor_loss      | -89.3    |
# |    critic_loss     | 6.36     |
# |    ent_coef        | 0.0281   |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15414    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 227      |
# |    time_elapsed    | 274      |
# |    total_timesteps | 62472    |
# | train/             |          |
# |    actor_loss      | -94.3    |
# |    critic_loss     | 8.76     |
# |    ent_coef        | 0.0275   |
# |    ent_coef_loss   | -1.54    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15592    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 227      |
# |    time_elapsed    | 277      |
# |    total_timesteps | 63180    |
# | train/             |          |
# |    actor_loss      | -93.1    |
# |    critic_loss     | 6.54     |
# |    ent_coef        | 0.0284   |
# |    ent_coef_loss   | 0.745    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15769    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 227      |
# |    time_elapsed    | 281      |
# |    total_timesteps | 64056    |
# | train/             |          |
# |    actor_loss      | -90.9    |
# |    critic_loss     | 7.03     |
# |    ent_coef        | 0.0289   |
# |    ent_coef_loss   | -0.646   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15988    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 227      |
# |    time_elapsed    | 285      |
# |    total_timesteps | 64896    |
# | train/             |          |
# |    actor_loss      | -93.4    |
# |    critic_loss     | 7.43     |
# |    ent_coef        | 0.0304   |
# |    ent_coef_loss   | -0.564   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16198    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 227      |
# |    time_elapsed    | 288      |
# |    total_timesteps | 65568    |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 10.9     |
# |    ent_coef        | 0.0309   |
# |    ent_coef_loss   | 0.278    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16366    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 227      |
# |    time_elapsed    | 291      |
# |    total_timesteps | 66276    |
# | train/             |          |
# |    actor_loss      | -92.6    |
# |    critic_loss     | 7.12     |
# |    ent_coef        | 0.0304   |
# |    ent_coef_loss   | 1.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16543    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 227      |
# |    time_elapsed    | 296      |
# |    total_timesteps | 67368    |
# | train/             |          |
# |    actor_loss      | -98.2    |
# |    critic_loss     | 8.33     |
# |    ent_coef        | 0.033    |
# |    ent_coef_loss   | -2.01    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16816    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 227      |
# |    time_elapsed    | 299      |
# |    total_timesteps | 68144    |
# | train/             |          |
# |    actor_loss      | -91.7    |
# |    critic_loss     | 6.1      |
# |    ent_coef        | 0.0331   |
# |    ent_coef_loss   | 2.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17010    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 227      |
# |    time_elapsed    | 303      |
# |    total_timesteps | 69056    |
# | train/             |          |
# |    actor_loss      | -97.5    |
# |    critic_loss     | 8.55     |
# |    ent_coef        | 0.0335   |
# |    ent_coef_loss   | -2.11    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17238    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 227      |
# |    time_elapsed    | 306      |
# ...
# ---------------------------------
# | time/              |          |
# |    episodes        | 928      |
# |    fps             | 228      |
# |    time_elapsed    | 918      |
# |    total_timesteps | 209804   |
# | train/             |          |
# |    actor_loss      | -169     |
# |    critic_loss     | 11.7     |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | 1.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 52425    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 932      |
# |    fps             | 228      |
# |    time_elapsed    | 926      |
# |    total_timesteps | 211652   |
# | train/             |          |
# |    actor_loss      | -174     |
# |    critic_loss     | 20.3     |
# |    ent_coef        | 0.0487   |
# |    ent_coef_loss   | 0.254    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 52887    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 936      |
# |    fps             | 228      |
# |    time_elapsed    | 931      |
# |    total_timesteps | 212640   |
# | train/             |          |
# |    actor_loss      | -169     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 53134    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 228      |
# |    time_elapsed    | 934      |
# |    total_timesteps | 213472   |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 15.6     |
# |    ent_coef        | 0.049    |
# |    ent_coef_loss   | -1.24    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 53342    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 944      |
# |    fps             | 228      |
# |    time_elapsed    | 941      |
# |    total_timesteps | 214772   |
# | train/             |          |
# |    actor_loss      | -175     |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.0511   |
# |    ent_coef_loss   | -0.13    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 53667    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 948      |
# |    fps             | 228      |
# |    time_elapsed    | 947      |
# |    total_timesteps | 216104   |
# | train/             |          |
# |    actor_loss      | -169     |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.051    |
# |    ent_coef_loss   | -0.902   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 54000    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 952      |
# |    fps             | 228      |
# |    time_elapsed    | 953      |
# |    total_timesteps | 217428   |
# | train/             |          |
# |    actor_loss      | -172     |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | -0.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 54331    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 956      |
# |    fps             | 227      |
# |    time_elapsed    | 964      |
# |    total_timesteps | 219860   |
# | train/             |          |
# |    actor_loss      | -172     |
# |    critic_loss     | 17.8     |
# |    ent_coef        | 0.0476   |
# |    ent_coef_loss   | 0.525    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 54939    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 960      |
# |    fps             | 227      |
# |    time_elapsed    | 970      |
# |    total_timesteps | 221152   |
# | train/             |          |
# |    actor_loss      | -179     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.0483   |
# |    ent_coef_loss   | -0.688   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55262    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 964      |
# |    fps             | 227      |
# |    time_elapsed    | 976      |
# |    total_timesteps | 222608   |
# | train/             |          |
# |    actor_loss      | -172     |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0485   |
# |    ent_coef_loss   | 0.608    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55626    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 968      |
# |    fps             | 227      |
# |    time_elapsed    | 980      |
# |    total_timesteps | 223376   |
# | train/             |          |
# |    actor_loss      | -169     |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.0489   |
# |    ent_coef_loss   | 0.684    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55818    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 972      |
# |    fps             | 227      |
# |    time_elapsed    | 990      |
# |    total_timesteps | 225660   |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 18.5     |
# |    ent_coef        | 0.0468   |
# |    ent_coef_loss   | 0.412    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 56389    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 976      |
# |    fps             | 227      |
# |    time_elapsed    | 995      |
# |    total_timesteps | 226904   |
# | train/             |          |
# |    actor_loss      | -174     |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.049    |
# |    ent_coef_loss   | -0.988   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 56700    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 227      |
# |    time_elapsed    | 1001     |
# |    total_timesteps | 228288   |
# | train/             |          |
# |    actor_loss      | -175     |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.0524   |
# |    ent_coef_loss   | -1.91    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 57046    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 984      |
# |    fps             | 227      |
# |    time_elapsed    | 1007     |
# |    total_timesteps | 229584   |
# | train/             |          |
# |    actor_loss      | -180     |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.052    |
# |    ent_coef_loss   | -0.692   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 57370    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 988      |
# |    fps             | 227      |
# |    time_elapsed    | 1014     |
# |    total_timesteps | 231220   |
# | train/             |          |
# |    actor_loss      | -181     |
# |    critic_loss     | 22.3     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | -0.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 57779    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 992      |
# |    fps             | 227      |
# |    time_elapsed    | 1021     |
# |    total_timesteps | 232512   |
# | train/             |          |
# |    actor_loss      | -182     |
# |    critic_loss     | 16.2     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | 0.31     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 58102    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 996      |
# |    fps             | 227      |
# |    time_elapsed    | 1025     |
# |    total_timesteps | 233484   |
# | train/             |          |
# |    actor_loss      | -177     |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.0507   |
# |    ent_coef_loss   | -0.701   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 58345    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 227      |
# |    time_elapsed    | 1032     |
# |    total_timesteps | 235136   |
# | train/             |          |
# |    actor_loss      | -186     |
# |    critic_loss     | 23.8     |
# |    ent_coef        | 0.0547   |
# |    ent_coef_loss   | -0.843   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 58758    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1004     |
# |    fps             | 227      |
# |    time_elapsed    | 1038     |
# |    total_timesteps | 236560   |
# | train/             |          |
# |    actor_loss      | -185     |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.0528   |
# |    ent_coef_loss   | 0.254    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59114    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1008     |
# |    fps             | 227      |
# |    time_elapsed    | 1046     |
# |    total_timesteps | 238252   |
# | train/             |          |
# |    actor_loss      | -185     |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.0533   |
# |    ent_coef_loss   | 0.433    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59537    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1012     |
# |    fps             | 227      |
# |    time_elapsed    | 1051     |
# |    total_timesteps | 239612   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 16.2     |
# |    ent_coef        | 0.0563   |
# |    ent_coef_loss   | 0.0615   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59877    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1016     |
# |    fps             | 227      |
# |    time_elapsed    | 1060     |
# |    total_timesteps | 241496   |
# | train/             |          |
# |    actor_loss      | -183     |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.0533   |
# |    ent_coef_loss   | -1.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 60348    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1020     |
# |    fps             | 227      |
# |    time_elapsed    | 1066     |
# |    total_timesteps | 243004   |
# | train/             |          |
# |    actor_loss      | -192     |
# |    critic_loss     | 16.5     |
# |    ent_coef        | 0.055    |
# |    ent_coef_loss   | -2.29    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 60725    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1024     |
# |    fps             | 227      |
# |    time_elapsed    | 1072     |
# |    total_timesteps | 244108   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0528   |
# |    ent_coef_loss   | 1.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 61001    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1028     |
# |    fps             | 227      |
# |    time_elapsed    | 1079     |
# |    total_timesteps | 245616   |
# | train/             |          |
# |    actor_loss      | -186     |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.054    |
# |    ent_coef_loss   | -0.636   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 61378    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1032     |
# |    fps             | 227      |
# |    time_elapsed    | 1086     |
# |    total_timesteps | 247140   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 23.8     |
# |    ent_coef        | 0.0542   |
# |    ent_coef_loss   | 2.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 61759    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 1036     |
# |    fps             | 227      |
# |    time_elapsed    | 1099     |
# |    total_timesteps | 250160   |
# | train/             |          |
# |    actor_loss      | -191     |
# |    critic_loss     | 20.1     |
# |    ent_coef        | 0.0508   |
# |    ent_coef_loss   | 1.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 62514    |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-72e53d687575> in <cell line: 2>()
#       1 clear_output()
# ----> 2 model.learn(total_timesteps=int(1e6), progress_bar=True)
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/sac/sac.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     305         progress_bar: bool = False,
#     306     ) -> SelfSAC:
# --> 307         return super().learn(
#     308             total_timesteps=total_timesteps,
#     309             callback=callback,
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345                 # Special case when the user passes `gradient_steps=0`
#     346                 if gradient_steps > 0:
# --> 347                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     348
#     349         callback.on_training_end()
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/sac/sac.py in train(self, gradient_steps, batch_size)
#     265             # Optimize the critic
#     266             self.critic.optimizer.zero_grad()
# --> 267             critic_loss.backward()
#     268             self.critic.optimizer.step()
#     269
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     523                 inputs=inputs,
#     524             )
# --> 525         torch.autograd.backward(
#     526             self, gradient, retain_graph, create_graph, inputs=inputs
#     527         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     265     # some Python versions print out the first line of a multi-line function
#     266     # calls in the traceback and some print out the last line
# --> 267     _engine_run_backward(
#     268         tensors,
#     269         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     742         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743     try:
# --> 744         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745             t_outputs, *args, **kwargs
#     746         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
model.save('/content/gdrive/MyDrive/Colab Notebooks/rl_summer_school/models/sac.zip')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model.load('/content/gdrive/MyDrive/Colab Notebooks/rl_summer_school/models/sac.zip')

# %% [markdown]
# ### Evaluating and visualizing the performance of trained model

# %%
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward:.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward: 823.06

# %%
t_env = DummyVecEnv([lambda: gym.make('Walker2d-v4', render_mode="rgb_array")])
state = t_env.reset()
frames = []

while True:
    action, _ = model.predict(state)
    state_next, r, done, info = t_env.step(action)
    frames.append(t_env.render())
    state = state_next
    if done.all():
        break

t_env.close()

# %%
def frames_to_video(frames, fps=24):
    fig = plt.figure(figsize=(frames[0].shape[1] / 100, frames[0].shape[0] / 100), dpi=100)
    ax = plt.axes()
    ax.set_axis_off()

    if len(frames[0].shape) == 2:  # Grayscale image
        im = ax.imshow(frames[0], cmap='gray')
    else:  # Color image
        im = ax.imshow(frames[0])

    def init():
        if len(frames[0].shape) == 2:
            im.set_data(frames[0], cmap='gray')
        else:
            im.set_data(frames[0])
        return im,

    def update(frame):
        if len(frames[frame].shape) == 2:
            im.set_data(frames[frame], cmap='gray')
        else:
            im.set_data(frames[frame])
        return im,

    interval = 1000 / fps
    anim = FuncAnimation(fig, update, frames=len(frames), init_func=init, blit=True, interval=interval)
    plt.close()
    return HTML(anim.to_html5_video())

frames_to_video(frames)
# Out:
# <video width="480" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...
